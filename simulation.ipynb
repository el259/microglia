# %% [markdown]
# ## ABM of Microglia, Astrocyte and Neurons Interaction in the hippocampus

# %% [markdown]
# ### Instructions to Run the Notebook Simulation

# %% [markdown]
# 1. Click 'Run All Cells' to execute the notebook.
# 2. Adjust parameters in the 'Interactive Model Page' when it appears to explore different scenarios.
# 3. Click 'Start' to begin the simulation. Optionally can move step by step, or all at once.
# 4. Click 'Stop' to end the simulation.
# 5. Review the plots and data generated to analyze the results of the simulation.
# 6. Save the notebook to retain your changes and results.
# 7. Repeat the process with different parameters to explore various outcomes.

# %% [markdown]
# ### Notes and Comments for Linux and/or Python Virtual Environments
# If you are using Linux it may be required to use a Python virtual environment, which allows you to install packages and libraries that may not already be installed if you are running the simulation locally.
#
# python3 -m venv simulation-env
# source simulation-env/bin/activate
#
# pip install LIST-PACKAGES

# %%
# DEFAULT VARIABLES

# World simulation
GRID_WIDTH:     int     = 33
GRID_HEIGHT:    int     = 33;
IS_TORUS:       bool    = True

# Microglia defaults
EAT_PROBABILITY:        float   = 0.70
SENSING_EFFICIENCY:     float   = 0.50


# Neuron defaults
DAMAGE_RATIO_THRESH:    float   = 1.5
HEALTHY_RATIO_THRESH:   float   = 1.0
DEATH_RATIO_THRESH:     float   = 2.0
HEALTHY_CHANCE:         float   = 0.20
DAMAGE_TO_DEATH_TICKS:  int     = 20
DEATH_CHANCE:           float   = 0.25
DAMAGE_CHANCE:          float   = 0.005
NEURON_DISTANCE:        int     = 5
DAMAGE_RADIUS:          int     = 3


# Num of initial agents
NUM_MICOGROGLIA:        int     = 5
NUM_HEALTHY_NEURONS:    int     = 5
NUM_DAMAGED_NEURONS:    int     = 10
NUM_DEAD_NEURONS:       int     = 10

# Visualization
STOP_MODE:              str     = "Damage cleared"
MAX_STEPS:              int     = 5000
FPS_LIMIT:              int     = 8
STEPS_PER_FRAME:        int     = 5

# %%
# ----------------------------------- model.py / agents.py ------------------------------------

from __future__ import annotations
from typing import Tuple, Set
from mesa import Agent, Model
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector
import numpy as np

class Neuron(Agent):
    """Neuron agent: healthy ↔ damaged → dead. Dead emits signals and waits for phagocytosis."""
    def __init__(self, unique_id, model, damaged: bool=False, dead: bool=False, healthy: bool=True, reach: int=2, ticks_damaged: int=0):
        self.unique_id = unique_id
        self.model = model
        self.pos = None
        self.damaged: bool = damaged
        self.dead: bool = dead
        self.healthy: bool = healthy and not (damaged or dead)
        self.reach: int = reach
        self.ticks_damaged: int = ticks_damaged
        # todo: self.lipid_amt: int

    def become_damaged(self):
        if self.dead or self.damaged:
            return
        self.healthy = False
        self.damaged = True
        self.ticks_damaged = 0
        x, y = self.pos
        self.model.residence[x, y] = True
        self.model.res_curr[x, y] = max(self.model.res_curr[x, y], 1)
        self.model.pro_inflam_val[x, y] = max(self.model.pro_inflam_val[x, y], 1)
        self.reach = 1

    # todo: If dead happens after time, inflammation will be max already probably so maybe change this
    def become_dead(self):
        if self.dead:
            return
        self.dead = True
        self.damaged = False
        self.healthy = False
        self.ticks_damaged = 0
        x, y = self.pos
        self.model.residence[x, y] = True
        self.model.res_curr[x, y] = max(self.model.res_curr[x, y], 1)
        self.model.pro_inflam_val[x, y] = max(self.model.pro_inflam_val[x, y], 1)
        self.reach = 0

    def become_healthy(self):
        if self.dead or self.healthy:
            return
        self.damaged = False
        self.healthy = True
        self.ticks_damaged = 0
        self.reach = 2

    def step(self):
        if self.pos is None:
            return
        if self.dead:
            return

        # --- params ---
        damage_ratio_thresh   = self.model.damage_ratio_thresh
        healthy_ratio_thresh  = self.model.healthy_ratio_thresh 
        p_damage              = self.model.damage_chance
        p_healthy             = self.model.healthy_chance
        damage_to_death_ticks = self.model.damage_to_death_ticks
        death_ratio_thresh    = self.model.death_ratio_thresh
        p_death               = self.model.death_chance
        eps = 1e-9

        x, y = self.pos
        neigh_pos = self.model.grid.get_neighborhood((x, y), moore=True, include_center=False, radius=1)
        if not neigh_pos:
            return

        pro_vals  = [self.model.pro_inflam_val[nx, ny]  for (nx, ny) in neigh_pos]
        anti_vals = [self.model.anti_inflam_val[nx, ny] for (nx, ny) in neigh_pos]
        mean_pro  = sum(pro_vals)  / len(pro_vals)
        mean_anti = sum(anti_vals) / len(anti_vals)
        mean_ratio = mean_pro / (mean_anti + eps)

        # --- Healthy → Damaged branch---
        if self.healthy and (mean_ratio >= damage_ratio_thresh):
            if self.model.random.random() < p_damage:
                self.become_damaged()
            return

        # --- Damaged branch ---
        if self.damaged:
            self.ticks_damaged += 1

            # Damaged → Dead
            if self.ticks_damaged >= damage_to_death_ticks:
                if mean_ratio >= death_ratio_thresh:
                    if self.model.random.random() < p_death:
                        self.become_dead()
                        return

            # Damaged → Healthy
            if mean_ratio <= healthy_ratio_thresh:
                if self.model.random.random() < p_healthy:
                    self.become_healthy()
            return


# todo: fill out Astrocyte agent details
class Astrocyte(Agent):
    pass

# todo: change Microglia logic to incorporate new Neuron types and new cytokines beyond minimum which allows operation
class Microglia(Agent):
    """Microglia with chemotaxis, surveillance, and phagocytosis; temperature-scaled motion."""
    def __init__(self, unique_id, model):
        self.unique_id = unique_id
        self.model = model
        self.pos = None
        self.wait_ticks: int = 0

    # Moving up the inflamation gradiant
    def pick_chemotaxis_target(self, pos: Tuple[int, int]) -> Tuple[int, int]:
        neigh = self.model.grid.get_neighborhood(pos, moore=True, include_center=True, radius=1)

        # Getting list of vals: {cell, invflamation amount}
        vals = []
        for cell in neigh:
            x, y = cell
            inflamation_amount = self.model.pro_inflam_val[x, y]
            vals.append((cell, inflamation_amount))

        # Getting the val with largest inflamation value
        max_val = max(v for _, v in vals)

        # Handling case where there is no single greatest value
        #    - Just chooses a random cell from neibors
        if all(v == max_val for _, v in vals):
            choices = [c for c in neigh if c != pos]
            return self.model.random.choice(choices) if choices else pos
        
        # Handling case where there is at least 1 greatest value
        #    - Randomly chooses cell from all largest value neibors
        candidates = [c for c, v in vals if v == max_val]
        return self.model.random.choice(candidates)

    # Moving 'randomly'
    def undirected_target(self, pos: Tuple[int, int]) -> Tuple[int, int]:
        neigh = self.model.grid.get_neighborhood(pos, moore=True, include_center=False, radius=1)
        return self.model.random.choice(neigh)

    def move_once(self):
        x, y = self.pos

        can_do_chemotaxis = self.model.random.random() < self.model.sensing_efficiency
        if can_do_chemotaxis:
            tx, ty = self.pick_chemotaxis_target((x, y))
        else:
            tx, ty = self.undirected_target((x, y))
        self.model.grid.move_agent(self, (tx, ty))

    def interact_here(self) -> bool:
        cellmates = self.model.grid.get_cell_list_contents([self.pos])
        neurons = [a for a in cellmates if isinstance(a, Neuron)]
        if not neurons:
            return False
        n: Neuron = neurons[0]
        if n.damaged or n.dead:  # CHANGE to allow phagocytosis on damaged and dead
            if self.model.random.random() < self.model.eat_probability:
                px, py = n.pos
                self.model.remove_neuron(n)
                if self.model.residence[px, py]:
                    self.model.residence[px, py] = False
                    self.model.dis_curr[px, py] = self.model.res_curr[px, py]
                    self.model.res_curr[px, py] = 0
                    self.model.dismantling[px, py] = True
            self.wait_ticks += 5
            return True
        else:
            self.wait_ticks += 2
            return True

    def step(self):
        if self.wait_ticks > 0:
            self.wait_ticks -= 1
            return

        # NetLogo resonance: one move per tick + a probabilistic extra move based on temperature
        # Expected moves ~= 1 + 0.05*(T-37) without unbounded multi-moves per tick
        speed = max(0.0, 1.0 + 0.05 * (72 - 37.0))
        moves = 1
        extra = speed - 1.0
        if extra > 0 and self.model.random.random() < extra:
            moves += 1

        for _ in range(moves):
            self.move_once()
            if self.interact_here():
                break

# todo: change Microglia logic to incorporate new Neuron types and new cytokines beyond minimum that allows operation
class SimulationModel(Model):
    def __init__(
        self,
        seed: int | None,
        
        # Simulation variables
        init_microglia: int,
        init_healthy_neuron: int,
        init_damaged_neuron: int,
        init_dead_neuron: int,

        # Microglia agent variables
        eat_probability: float,
        sensing_efficiency: float,

        # Neuron agent variables
        damage_chance: float,
        neuron_distance: int,
        damage_radius: int,

        
        # New neuron variables
        # TODO: Consider moving into smaller scope if they aren't being passed into the SimulationModel, such as into neuron class...
        damage_ratio_thresh: float = DAMAGE_RATIO_THRESH,
        healthy_ratio_thresh: float = HEALTHY_RATIO_THRESH,
        healthy_chance: float = HEALTHY_CHANCE,
        damage_to_death_ticks: int = DAMAGE_TO_DEATH_TICKS,
        death_ratio_thresh: float = DEATH_RATIO_THRESH,
        death_chance: float = DEATH_CHANCE,
    ):
        super().__init__(seed=seed)
        self.grid = MultiGrid(GRID_WIDTH, GRID_HEIGHT, IS_TORUS)

        # Counters
        self._uid: int = 0
        self.steps: int = 0

        # Microglia params
        self.eat_probability = float(eat_probability)
        self.sensing_efficiency = float(sensing_efficiency)

        # Neuron params
        self.damage_chance = float(damage_chance)
        self.neuron_distance = int(neuron_distance)
        self.damage_radius = int(damage_radius)
        # New neuron params from recent update
        self.damage_ratio_thresh = float(damage_ratio_thresh) 
        self.healthy_ratio_thresh = float(healthy_ratio_thresh)
        self.healthy_chance = float(healthy_chance)
        self.damage_to_death_ticks = int(damage_to_death_ticks) 
        self.death_ratio_thresh = float(death_ratio_thresh)
        self.death_chance = float(death_chance)

        # Patch fields
        shp = (GRID_WIDTH, GRID_HEIGHT)
        self.pro_inflam_val = np.zeros(shp, dtype=int)
        self.anti_inflam_val = np.zeros(shp, dtype=int)
        self.residence = np.zeros(shp, dtype=bool)
        self.res_curr = np.zeros(shp, dtype=int)
        self.dismantling = np.zeros(shp, dtype=bool)
        self.dis_curr = np.zeros(shp, dtype=int)

        # Agent lists
        self.microglia: list[Microglia] = []
        self.neurons: list[Neuron] = []
        self.astrocytes: list[Astrocyte] = []

        # Neurons
        for _ in range(init_healthy_neuron):
            n = Neuron(self.next_id(), self, damaged=False, dead=False)
            self._place_random(n)
            self.neurons.append(n)

        for _ in range(init_damaged_neuron):
            n = Neuron(self.next_id(), self, damaged=True, dead=False)
            self._place_random(n)
            self.neurons.append(n)
            x, y = n.pos
            self.residence[x, y] = True
            self.res_curr[x, y] = 1
            self.pro_inflam_val[x, y] = 1

        for _ in range(init_dead_neuron):
            n = Neuron(self.next_id(), self, damaged=False, dead=True)
            self._place_random(n)
            self.neurons.append(n)
            x, y = n.pos
            self.residence[x, y] = True
            self.res_curr[x, y] = 1
            self.pro_inflam_val[x, y] = 1


        # Initializing microglia
        for _ in range(init_microglia):
            m = Microglia(self.next_id(), self)
            self._place_random(m)
            self.microglia.append(m)


        # Data
        self.datacollector = DataCollector(
            model_reporters={
                "step": lambda m: m.steps,
                "damaged_neurons": lambda m: sum(1 for n in m.neurons if n.pos is not None and n.damaged),
                "dead_neurons": lambda m: sum(1 for n in m.neurons if n.pos is not None and n.dead),
                "healthy_neurons": lambda m: sum(1 for n in m.neurons if n.pos is not None and not n.damaged),
                "total_pro_inflammation": lambda m: int(m.pro_inflam_val.sum()),
                "total_anti_inflammation": lambda m: int(m.anti_inflam_val.sum()),
                "mean_pro_inflammation": lambda m: float(m.pro_inflam_val.mean()),
                "mean_anti_inflammation": lambda m: float(m.anti_inflam_val.mean()),
                "microglia": lambda m: len(m.microglia),
            }
        )

    def next_id(self) -> int:
        self._uid += 1
        return self._uid

    def _place_random(self, agent):
        x = self.random.randrange(GRID_WIDTH)
        y = self.random.randrange(GRID_HEIGHT)
        self.grid.place_agent(agent, (x, y))

    def _torus_distance(self, a: tuple[int, int], b: tuple[int, int]) -> float:
        dx = abs(a[0] - b[0])
        dy = abs(a[1] - b[1])
        if self.grid.torus:
            dx = min(dx, GRID_WIDTH - dx)
            dy = min(dy, GRID_HEIGHT - dy)
        return (dx * dx + dy * dy) ** 0.5

    def remove_neuron(self, neuron: Neuron):
        if neuron.pos is not None:
            self.grid.remove_agent(neuron)
            neuron.pos = None

    def _diffuse_inflammation(self):
        coords = list(zip(*np.where(self.residence)))
        for x, y in coords:
            r = self.res_curr[x, y]
            if r <= self.damage_radius - 1:
                xs = range(x - r, x + r + 1)
                ys = range(y - r, y + r + 1)
                for xi in xs:
                    for yi in ys:
                        xi2 = xi % GRID_WIDTH
                        yi2 = yi % GRID_HEIGHT
                        if max(abs(xi - x), abs(yi - y)) <= r:
                            self.pro_inflam_val[xi2, yi2] += 1
                self.res_curr[x, y] = r + 1

    def _dismantle_inflammation(self):
        coords = list(zip(*np.where(self.dismantling)))
        to_stop = []
        for x, y in coords:
            r = self.dis_curr[x, y]
            xs = range(x - r, x + r + 1)
            ys = range(y - r, y + r + 1)
            for xi in xs:
                for yi in ys:
                    xi2 = xi % GRID_WIDTH
                    yi2 = yi % GRID_HEIGHT
                    if max(abs(xi - x), abs(yi - y)) <= r:
                        self.pro_inflam_val[xi2, yi2] = max(0, self.pro_inflam_val[xi2, yi2] - 1)
            r -= 1
            if r <= 0:
                to_stop.append((x, y))
            else:
                self.dis_curr[x, y] = r
        for x, y in to_stop:
            self.dismantling[x, y] = False
            self.dis_curr[x, y] = 0

    def step(self):
        self.random.shuffle(self.microglia)
        for mg in self.microglia:
            mg.step()
        for n in self.neurons:
            n.step()
        if self.steps % 5 == 0:
            self._diffuse_inflammation()
            self._dismantle_inflammation()
        self.datacollector.collect(self)
        self.steps += 1

    def all_damaged_cleared(self) -> bool:
        return all((not n.damaged) or (n.pos is None) or (not n.dead) for n in self.neurons)

# %%
# app.py
from __future__ import annotations
import argparse
import os
import io
import time
import numpy as np
import pandas as pd
import altair as alt
import solara
from solara.lab import use_task

# CLI-only pyplot
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas




# ----------------- Solara UI -----------------
@solara.component
def Page():
    solara.Title("Microglia–Neuron ABM — Live")

    # ----------- Controls / parameters -----------
    steps, set_steps = solara.use_state(MAX_STEPS)   # tick cap
    stop_mode, set_stop_mode = solara.use_state("Damaged cleared")

    # Number of agents knobs
    microglia, set_microglia = solara.use_state(NUM_MICOGROGLIA)
    healthy_neurons, set_hn = solara.use_state(NUM_HEALTHY_NEURONS)
    damaged_neurons, set_dn = solara.use_state(NUM_DAMAGED_NEURONS)
    dead_neurons, set_dn = solara.use_state(NUM_DEAD_NEURONS)

    eat, set_eat = solara.use_state(EAT_PROBABILITY)
    sense, set_sense = solara.use_state(SENSING_EFFICIENCY)
    damage, set_damage = solara.use_state(DAMAGE_CHANCE)
    ndist, set_ndist = solara.use_state(NEURON_DISTANCE)
    radius, set_radius = solara.use_state(DAMAGE_RADIUS)


    # Performance knobs
    fps_limit, set_fps_limit = solara.use_state(FPS_LIMIT)                    # max frames/sec
    steps_per_frame, set_steps_per_frame = solara.use_state(STEPS_PER_FRAME)  # sim ticks per render



    # ----------- Simulation state -----------
    model_ref = solara.use_reactive(None)               # holds SimulationModel
    step_count, set_step_count = solara.use_state(0)

    running, set_running = solara.use_state(False)      # "UI thinks it's running"
    stop_ref = solara.use_reactive(False)               # hard stop signal the loop checks
    loop_active_ref = solara.use_reactive(False)        # is the runner loop currently executing

    frame_png, set_frame_png = solara.use_state(None)

    # metrics df that feeds charts
    metrics_df, set_metrics_df = solara.use_state(
        pd.DataFrame(columns=[
            "step",
            "healthy_neurons",
            "damaged_neurons",
            "total_inflammation",
            "mean_inflammation",
            "microglia",
        ])
    )



    # ----------- persistent matplotlib fig / ax / image -----------
    fig_grid, ax_grid, img_artist = solara.use_memo(
        lambda: init_grid_figure(),
        dependencies=[]
    )



    # ----------- model setup / reset -----------
    def build_model():
        # Initializing fresh model
        model = SimulationModel(
            init_microglia=microglia,
            init_healthy_neuron=healthy_neurons,
            init_damaged_neuron=damaged_neurons,
            init_dead_neuron=dead_neurons,
            eat_probability=eat,
            sensing_efficiency=sense,
            damage_chance=damage,
            neuron_distance=ndist,
            damage_radius=radius,
            seed=None
        )

        # Main loop of simulation
        steps = 0;
        for _ in range(steps):
            is_finished = not any((n.pos is not None) and n.damaged for n in model.neurons) #Change: Moved check into its own statement for readablility

            if is_finished:
                break

            model.step()

        # Passing model into solara's references
        model_ref.value = model
        set_step_count(0)

        # draw first frame
        render_frame(model)

        # seed charts with an initial snapshot row, even before first .step()
        seed_metrics_from_model(model)

    # run once on mount
    solara.use_effect(build_model, [])



    # ----------- stopping conditions -----------
    def should_stop(m: SimulationModel) -> bool:
        if stop_mode == "Damaged cleared":
            # CHANGE: inline the correct logic; don't call m.all_damaged_cleared()
            if not any((n.pos is not None) and n.damaged for n in m.neurons):  # CHANGE
                return True
        elif stop_mode == "Inflammation is zero":
            # CHANGE: use pro and anti arrays; no inflam_val field on model anymore
            if int((m.pro_inflam_val + m.anti_inflam_val).sum()) == 0:
                return True
        elif stop_mode == "No neurons left":
            if all(n.pos is None for n in m.neurons):
                return True
        elif stop_mode == "No microglia left":
            if len(m.microglia) == 0:
                return True
        if m.steps >= steps:
            return True
        return False



    # ----------- metrics update helpers -----------
    def compute_full_metrics_df(m: SimulationModel) -> pd.DataFrame:
        """
        Pull the current DataCollector dataframe and return a fresh DataFrame
        (exactly like the working notebook).
        """
        if m is None:
            return pd.DataFrame(columns=[
                "step",
                "healthy_neurons",
                "damaged_neurons",
                "total_inflammation",
                "mean_inflammation",
                "microglia",
            ])

        # This is what Mesa DataCollector gives us.
        df_full = m.datacollector.get_model_vars_dataframe()

        # Note: In your model, datacollector.collect(self) runs every step().
        # At t=0 (before any step()), df_full will be empty.
        if df_full.shape[0] == 0:
            # fabricate one row from current model state so charts aren't blank
            fabricated = pd.DataFrame([{
                "step": m.steps,
                "healthy_neurons": len([n for n in m.neurons if (n.pos is not None and not n.damaged)]),
                "damaged_neurons": len([n for n in m.neurons if (n.pos is not None and n.damaged)]),
                # CHANGE: use pro inflammatory field but attach to general inflammation key
                "total_inflammation": float(np.sum(m.pro_inflam_val)),
                "mean_inflammation": float(np.mean(m.pro_inflam_val)),
                "microglia": len([mg for mg in m.microglia if mg.pos is not None]),
            }])
            return fabricated.reset_index(drop=True)

        # CHANGE: map DataCollector's pro inflammation columns so it matches
        df_full = df_full.copy()
        if "total_inflammation" not in df_full.columns and "total_pro_inflammation" in df_full.columns:
            df_full["total_inflammation"] = df_full["total_pro_inflammation"]
        if "mean_inflammation" not in df_full.columns and "mean_pro_inflammation" in df_full.columns:
            df_full["mean_inflammation"] = df_full["mean_pro_inflammation"]

        return df_full.reset_index(drop=True)

    def seed_metrics_from_model(m: SimulationModel):
        df_now = compute_full_metrics_df(m)
        # give Altair a brand new object so Solara sees a change
        set_metrics_df(df_now.copy())

    def refresh_metrics_from_model(m: SimulationModel):
        """
        Called every visual frame while running.
        Replaces the whole metrics_df, like the notebook.
        """
        df_now = compute_full_metrics_df(m)
        set_metrics_df(df_now.copy())



    # ----------- figure/PNG update -----------
    def render_frame(m: SimulationModel):
        """
        Update the persistent matplotlib Figure and push PNG bytes to frame_png.
        This is what drives the visual grid.
        """
        if m is None:
            return

        # CHANGE: heatmap is pro_inflam_val
        heatmap = m.pro_inflam_val.T
        img_artist.set_data(heatmap)

        h_map, w_map = heatmap.shape
        img_artist.set_extent((0, w_map, 0, h_map))
        ax_grid.set_xlim(0, w_map)
        ax_grid.set_ylim(0, h_map)
        ax_grid.set_aspect("equal")

        # clear previous agent markers
        for artist in list(ax_grid.lines):
            artist.remove()

        # draw neurons
        for n in m.neurons:
            if n.pos is None:
                continue
            x, y = n.pos
            ax_grid.plot(
                x, y,
                marker="s", ms=5, mec="black",
                mfc=("red" if n.damaged else "limegreen"),
            )
            # Note: mec is edge color, mfc is fill color

        # draw microglia
        for mg in m.microglia:
            if mg.pos is None:
                continue
            x, y = mg.pos
            ax_grid.plot(
                x, y,
                marker="o", ms=5, mec="black", mfc="orange",
            )
            # Note: mec is edge color, mfc is fill color

        ax_grid.set_title(f"Step {m.steps}")

        # rasterize -> PNG bytes
        buf = io.BytesIO()
        canvas = FigureCanvas(fig_grid)
        canvas.draw()
        fig_grid.savefig(buf, format="png", dpi=80)
        set_frame_png(buf.getvalue())



    # ----------- main sim loop -----------
    @use_task
    def runner():
        """
        Manual-start loop (doesn't auto-run on load).
        - advances the model in batches (steps_per_frame)
        - refreshes frame and metrics each batch
        - throttles FPS
        - respects stop button and stop conditions
        """
        if loop_active_ref.value:
            return
        loop_active_ref.value = True

        while True:
            if stop_ref.value:
                break

            m = model_ref.value
            if m is None:
                break

            if should_stop(m):
                break

            # advance the sim multiple ticks before we redraw
            for _ in range(steps_per_frame):
                if stop_ref.value or should_stop(m):
                    break
                m.step()

            # update UI-visible state
            set_step_count(m.steps)
            render_frame(m)
            refresh_metrics_from_model(m)  # <--- pull full DataCollector df each frame

            # throttle FPS
            if fps_limit > 0:
                time.sleep(1.0 / float(fps_limit))

            # if UI toggled running off, bail
            if not running:
                break

        loop_active_ref.value = False
        stop_ref.value = False
        if running:
            set_running(False)



    # ----------- button handlers -----------
    def on_reset():
        # kill any active loop
        set_running(False)
        stop_ref.value = True
        # CHANGE: set the reactive flag value; don't recreate it
        loop_active_ref.value = False
        build_model()

    def on_start():
        if loop_active_ref.value:
            return
        stop_ref.value = False
        set_running(True)
        runner()  # explicit start

    def on_stop():
        set_running(False)
        stop_ref.value = True  # runner will exit on next iteration

    def step_once():
        m = model_ref.value
        if m is None:
            return
        if should_stop(m):
            return
        # single step for manual advance
        m.step()
        set_step_count(m.steps)
        render_frame(m)
        refresh_metrics_from_model(m)



    # ----------- Altair charts -----------
    def chart_neurons(df: pd.DataFrame):
        if df.empty:
            return alt.Chart(pd.DataFrame({"step": [], "value": [], "type": []})).mark_line()
        tidy = pd.melt(
            df[["step", "healthy_neurons", "damaged_neurons"]],
            id_vars="step", var_name="type", value_name="value"
        )
        return (
            alt.Chart(tidy)
            .mark_line()
            .encode(
                x=alt.X("step:Q", title="Step"),
                y=alt.Y("value:Q", title="Count"),
                color=alt.Color("type:N", title="Neuron type"),
            )
            .properties(title="Neurons", width=350, height=180)
        )

    def chart_inflammation(df: pd.DataFrame):
        if df.empty:
            return alt.Chart(pd.DataFrame({"step": [], "value": [], "type": []})).mark_line()
        tidy = pd.melt(
            df[["step", "total_inflammation", "mean_inflammation"]],
            id_vars="step", var_name="type", value_name="value"
        )
        return (
            alt.Chart(tidy)
            .mark_line()
            .encode(
                x=alt.X("step:Q", title="Step"),
                y=alt.Y("value:Q", title="Inflammation"),
                color=alt.Color("type:N", title="Metric"),
            )
            .properties(title="Inflammation", width=350, height=180)
        )

    def chart_microglia(df: pd.DataFrame):
        if df.empty:
            return alt.Chart(pd.DataFrame({"step": [], "microglia": []})).mark_line()
        return (
            alt.Chart(df)
            .mark_line()
            .encode(
                x=alt.X("step:Q", title="Step"),
                y=alt.Y("microglia:Q", title="# Microglia"),
            )
            .properties(title="Microglia", width=350, height=180)
        )



    # ----------- UI Layout -----------
    with solara.Columns([1, 1]):
        # LEFT: controls + grid
        with solara.Column():
            with solara.Card("Parameters"):
                value_style = {
                    "width": "6ch",
                    "fontFamily": "monospace",
                    "textAlign": "center",
                    "paddingRight": "8px",
                }

                def row_with_value(val, widget_callable):
                    with solara.Row():
                        solara.Text(f"{val}", style=value_style)
                        widget_callable()

                row_with_value(steps, lambda: solara.SliderInt("steps (max)", value=steps, min=50, max=5000, on_value=set_steps))

                row_with_value(microglia, lambda: solara.SliderInt("microglia", value=microglia, min=1, max=50, on_value=set_microglia))
                row_with_value(healthy_neurons, lambda: solara.SliderInt("healthy neurons", value=healthy_neurons, min=0, max=200, on_value=set_hn))
                row_with_value(damaged_neurons, lambda: solara.SliderInt("damaged neurons", value=damaged_neurons, min=0, max=200, on_value=set_dn))
                row_with_value(dead_neurons, lambda: solara.SliderInt("dead neurons", value=dead_neurons, min=0, max=200, on_value=set_dn))

                row_with_value(eat, lambda: solara.SliderFloat("eat prob", value=eat, min=0.0, max=1.0, on_value=set_eat))
                row_with_value(sense, lambda: solara.SliderFloat("sense", value=sense, min=0.0, max=1.0, on_value=set_sense))
                row_with_value(damage, lambda: solara.SliderFloat("damage chance", value=damage, min=0.0, max=0.1, step=0.001, on_value=set_damage))
                row_with_value(ndist, lambda: solara.SliderInt("neuron link dist", value=ndist, min=1, max=10, on_value=set_ndist))
                row_with_value(radius, lambda: solara.SliderInt("inflam radius", value=radius, min=1, max=10, on_value=set_radius))

                solara.Select(
                    label="Stop when",
                    value=stop_mode,
                    values=[
                        "Damaged cleared",
                        "Tick cap only",
                        "Inflammation is zero",
                        "No neurons left",
                        "No microglia left",
                    ],
                    on_value=set_stop_mode,
                )

                row_with_value(fps_limit, lambda: solara.SliderInt("FPS limit", value=fps_limit, min=1, max=30, on_value=set_fps_limit))
                row_with_value(steps_per_frame, lambda: solara.SliderInt("Steps per frame", value=steps_per_frame, min=1, max=50, on_value=set_steps_per_frame))

                with solara.Row():
                    solara.Button("Reset", on_click=on_reset, color="secondary")
                    solara.Button("Start", on_click=on_start, color="primary", disabled=loop_active_ref.value)
                    solara.Button("Stop", on_click=on_stop, color="warning", disabled=not loop_active_ref.value)
                    solara.Button("Step once", on_click=step_once)

                solara.Text(f"Current step: {step_count}")

            if frame_png:
                solara.Image(frame_png, format="png", width="100%")

        # RIGHT: charts
        with solara.Column():
            with solara.Card("Metrics (live)"):
                # we call chart_* every render using current metrics_df
                solara.FigureAltair(chart_neurons(metrics_df))
                solara.FigureAltair(chart_inflammation(metrics_df))
                solara.FigureAltair(chart_microglia(metrics_df))




# ----------- helper for persistent figure -----------
def init_grid_figure():
    """
    Create and return a persistent matplotlib Figure, Axes, and base image artist.
    We'll mutate these instead of creating a new figure per frame.
    """
    fig = Figure(figsize=(4, 4), dpi=80)
    ax = fig.add_subplot(1, 1, 1)

    init_data = np.zeros((10, 10))
    img_artist = ax.imshow(init_data.T, origin="lower", interpolation="nearest")
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title("Step 0")
    fig.tight_layout()

    return fig, ax, img_artist


# Only auto-run CLI when executed directly, not when Solara imports us
#if __name__ == "__main__" and not os.environ.get("SOLARA_SERVER"):
#    main()

Page()

# %% [markdown]
# Note:
#
# - Green is healthy neuron
# - Red is unhealthy neuron
# - Orange is microglia
